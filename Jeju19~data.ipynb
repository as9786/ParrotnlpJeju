# %% [markdown]
# <a href="https://colab.research.google.com/github/as9786/ParrotnlpJeju/blob/main/Jeju19~data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#모듈 불러오기
import pandas as pd
import numpy as np
import re
import codecs
import os
import nltk
nltk.download('punkt')
from nltk import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# Collecting git+https://github.com/haven-jeon/PyKoSpacing.git
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to /tmp/pip-req-build-pjk1vh5l
#   Running command git clone -q https://github.com/haven-jeon/PyKoSpacing.git /tmp/pip-req-build-pjk1vh5l
# Requirement already satisfied (use --upgrade to upgrade): pykospacing==0.4 from git+https://github.com/haven-jeon/PyKoSpacing.git in /usr/local/lib/python3.7/dist-packages
# Requirement already satisfied: tensorflow==2.4.0 in /usr/local/lib/python3.7/dist-packages (from pykospacing==0.4) (2.4.0)
# Requirement already satisfied: keras>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from pykospacing==0.4) (2.4.3)
# Requirement already satisfied: h5py==2.10.0 in /usr/local/lib/python3.7/dist-packages (from pykospacing==0.4) (2.10.0)
# Requirement already satisfied: argparse>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from pykospacing==0.4) (1.4.0)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0->pykospacing==0.4) (2.4.1)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0->pykospacing==0.4) (1.12.1)
# Requirement already satisfied: grpcio~=1.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0->pykospacing==0.4) (1.32.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0->pykospacing==0.4) (1.12)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0->pykospacing==0.4) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0->pykospacing==0.4) (3.12.4)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0->pykospacing==0.4) (0.2.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0->pykospacing==0.4) (0.3.3)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0->pykospacing==0.4) (0.12.0)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0->pykospacing==0.4) (1.19.5)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0->pykospacing==0.4) (1.1.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0->pykospacing==0.4) (1.1.2)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0->pykospacing==0.4) (1.6.3)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0->pykospacing==0.4) (0.36.2)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0->pykospacing==0.4) (3.7.4.3)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0->pykospacing==0.4) (2.4.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0->pykospacing==0.4) (1.15.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras>=2.4.3->pykospacing==0.4) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras>=2.4.3->pykospacing==0.4) (3.13)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (0.4.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (2.23.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (56.1.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (1.28.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (3.10.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (2020.12.5)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (4.2.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (3.4.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0->pykospacing==0.4) (0.4.8)
# Building wheels for collected packages: pykospacing
#   Building wheel for pykospacing (setup.py) ... done
#   Created wheel for pykospacing: filename=pykospacing-0.4-cp37-none-any.whl size=2255638 sha256=cc0d254cfcb7d7cecc94c135017b030838599fe230183bb82ec15b64d3ba0eed
#   Stored in directory: /tmp/pip-ephem-wheel-cache-t05hqkj2/wheels/4d/45/58/e26cb2b7f6a063d234158c6fd1e5700f6e15b99d67154340ba
# Successfully built pykospacing

# %%
from pykospacing import spacing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PATH = '/content/drive/MyDrive/jejutxt'

# %%
je = []
ko = []

# %%
for name in os.listdir(PATH):
  raw = codecs.open(f"{PATH}/{name}", 'r', 'utf8').read()
  sents = re.findall('[0-9]{6}.+[(][\S\s]+?[)][\n\r]+', raw) # 제주어-표준어 문장단위 추출
  # 페이지에 걸쳐 있는 문장 제외 / 
  sents = [sent for sent in sents if "구술" not in sent and not re.search(r'[\ue000-\uffff]', sent) and not re.search('[)][(]', sent) and re.search('[가-힣]+.+[(]', sent)] 
  je_tmp = [re.search('[가-힣]+.+[(]', sent).group()[:-1] for sent in sents]
  je_tmp = [re.sub('[\d()]', '', sent) for sent in je_tmp]
  ko_tmp = [re.search('[(].+[)]', sent, re.S).group()[1:-1] for sent in sents]
  je.extend(je_tmp)
  ko.extend(ko_tmp)

# %%
koerror = []
for sent in ko:
  if re.search('[()]',sent):
    koerror.append(sent)

# %%
error = []
for i in koerror:
  error.append(ko.index(i))

# %%
for i in error:
  del je[i]
  del ko[i]

# %%
je[:20]
# Out:
# ['동부락, 이 마을, 신촌 마을이 그냥 신촌? 여기 동부락이우꽈?',
#  '이디 동동.',
#  '동동? 동동예. 그 이 마을이 언제 형성뒌 건 알아지쿠과?',
#  '몰라. 난.',
#  '이 마을의 형성?',
#  '옛날엔 숙군이옌 헤서 숙군. 숙군인디 이젠 신촌이옌 옛날엔 숙군.',
#  '숙군이예?',
#  '응.',
#  '숙군이?',
#  '신촌이옌 안헤영 숙군이렌 헷엇다고예?',
#  '숙군이라고 이 마을이 숙어지니까 숙군.',
#  '아아, 마을이 숙어지니까.',
#  '이 신촌이 어디가도 보이질 안허여.',
#  '아아.',
#  '숙어지니까 숙군? 그믄 숙군이엇을 때는 조천에 들어가낫수과?',
#  '조천읍에.',
#  '조천읍 숙군리?',
#  '조천 면 숙군리? 숙군리?',
#  '숙군.',
#  '숙군.']

# %%
ko[:20]
# Out:
# ['동부락,\n이 마을, 신촌 마을이 그냥 신촌? 여기 동부락입니까?',
#  '여기 동동.',
#  '동동? 동동이요.\n그 이 마을이 언제 형성된 건 알아지겠습니까?',
#  '몰라. 나는.',
#  '이 마을의 형성?',
#  '옛날\n엔 ‘숙군’이라고 해서 ‘숙군’. ‘숙군’인데 이젠 신촌이라고 옛날엔 ‘숙군’.',
#  '‘숙군’이요?',
#  '응.',
#  '‘숙군’이?',
#  '신촌이라고 안하고 ‘숙군’이라고 했었다\n고요?',
#  '‘숙군’이라고 이 마을이 숙어지니\n까 ‘숙군’.',
#  '아아, 마을이 숙어지니까.',
#  '이 신촌이 어디가도 보이질 않아.',
#  '아아.',
#  '숙어지니\n까 ‘숙군’? 그러면 ‘숙군’이었을 때는 조천에 들어갔었습니까?',
#  '조천읍에.',
#  '조천읍 숙군리?',
#  '조천 면 ‘숙군리’? ‘숙군리’?',
#  '‘숙군’',
#  '‘숙군’.']

# %%
print(len(je))
print(len(ko))
# Out:
# 94044
# 94044

# %%
# 공백문자 a로 변환
ko2 = [re.sub('[\n\r\t]','a',sent) for sent in ko]

# %%
ko2[:10]
# Out:
# ['동부락,a이 마을, 신촌 마을이 그냥 신촌? 여기 동부락입니까?',
#  '여기 동동.',
#  '동동? 동동이요.a그 이 마을이 언제 형성된 건 알아지겠습니까?',
#  '몰라. 나는.',
#  '이 마을의 형성?',
#  '옛날a엔 ‘숙군’이라고 해서 ‘숙군’. ‘숙군’인데 이젠 신촌이라고 옛날엔 ‘숙군’.',
#  '‘숙군’이요?',
#  '응.',
#  '‘숙군’이?',
#  '신촌이라고 안하고 ‘숙군’이라고 했었다a고요?']

# %%
# a가 포함되지 않은 표준어
ko4 = [sent for sent in ko2 if not re.search('[가-힣]*[a][가-힣]*',sent) ]

# %%
ko4[:10]
# Out:
# ['여기 동동.',
#  '몰라. 나는.',
#  '이 마을의 형성?',
#  '‘숙군’이요?',
#  '응.',
#  '‘숙군’이?',
#  '아아, 마을이 숙어지니까.',
#  '이 신촌이 어디가도 보이질 않아.',
#  '아아.',
#  '조천읍에.']

# %%
# 표준어 단어 사전 만들기
ko_word = word_tokenize(str(ko4))
ko_word[:10]
# Out:
# ['[', "'여기", '동동', '.', "'", ',', "'몰라", '.', '나는', '.']

# %%
#한국어를 제외한 문자열 제외
ko_word = [sent for sent in ko_word if not re.match('[^가-힣]',sent)]

# %%
ko_word[:20]
# Out:
# ['동동',
#  '나는',
#  '마을의',
#  '형성',
#  '숙군',
#  '이요',
#  '숙군',
#  '이',
#  '마을이',
#  '숙어지니까',
#  '신촌이',
#  '어디가도',
#  '보이질',
#  '않아',
#  '숙군리',
#  '면',
#  '숙군리',
#  '숙군리',
#  '숙군',
#  '숙군']

# %%
# 표준어 단어 사전
kovoca = set(ko_word)
len(kovoca)
# Out:
# 21982

# %%
kof = []
for sent in ko2:
  if re.search('[가-힣]*[a]+[가-힣]*',sent):
    a = re.search('[가-힣]*[a]+[가-힣]*',sent).group()
    b = re.sub('a','',a)
    if b in kovoca:
      c = re.sub('a','',sent)
      kof.append(c)
    else:
      d = re.sub('a','',sent)
      kof.append(spacing(d)) 
  else:
    kof.append(sent)

# %%
kof
# Out:
# ['동부락,이 마을, 신촌 마을이 그냥 신촌? 여기 동부락입니까?',
#  '여기 동동.',
#  '동동? 동동이요.그 이 마을이 언제 형성된 건 알아지겠습니까?',
#  '몰라. 나는.',
#  '이 마을의 형성?',
#  '옛날엔 ‘숙군’이라고 해서 ‘숙군’. ‘숙군’인데 이젠 신촌이라고 옛날엔 ‘숙군’.',
#  '‘숙군’이요?',
#  '응.',
#  '‘숙군’이?',
#  '신촌이라고 안하고 ‘숙군’이라고 했었다고요?',
#  '‘숙군’이라고 이 마을이 숙어지니까 ‘숙군’.',
#  '아아, 마을이 숙어지니까.',
#  '이 신촌이 어디가도 보이질 않아.',
#  '아아.',
#  '숙어지니까 ‘숙군’? 그러면 ‘숙군’이었을 때는 조천에 들어갔었습니까?',
#  '조천읍에.',
#  '조천읍 숙군리?',
#  '조천 면 ‘숙군리’? ‘숙군리’?',
#  '‘숙군’',
#  '‘숙군’.',
#  '이 마을은 신촌이잖아요.',
#  '예.',
#  '‘숙꾼’?',
#  '‘숙꾼’이 아니고 ‘수군’이었어.',
#  '아아.',
#  '예.',
#  '이 신촌 향사가.',
#  '예에.',
#  '그러니까 이 옛날 시대에는 이 ‘수군’이라고 했죠. ‘수군’.',
#  '‘수군’이요.',
#  '머리 수자 수군.',
#  '예.',
#  '예. 저 문화재.',
#  '예. 옛날 신촌마을은 조천 옆에 ‘수군’이라는 이름으로 있었다?',
#  '똑똑한 사람이 많이 나왔군요?',
#  '아아.',
#  '편안 강씨, 강씨하고, 홍씨하고.',
#  '홍씨요?',
#  '예. 권세, 지금은 아주 몰락해가지고 뭐 허허.',
#  '아아, 그렇게도 하네요.지금은 몰락해버리고요.',
#  '축 하나 쓰려고 해도 날 빌어 가야 돼. 헤헤헤헤.',
#  '아아.',
#  '조씨.',
#  '아아. 그러면 원래 신촌이라는 이름은 언제쯤 만들어졌는가요?',
#  '그거는 채 그건 기억을 못 합니다. 언제 만들어졌는지.',
#  '그러면 조천 이름 옆에 새로 만든 촌이니까 신촌이라고 했는가요?',
#  '그러면 조천에 소속되진 않았군요. 원래요?',
#  '그렇죠.',
#  '아아.',
#  '한계가 딱 있어요. 경계가.',
#  '원당봉? 원당봉?',
#  '원당봉 서쪽으로는 시 관 내고, 동쪽으로는 이 조천읍 관 내고.',
#  '음. 읍 관내요.',
#  '‘원당봉’이 반은 저 삼양이고반은 신촌 거주.',
#  '아아.',
#  '이 마을에는 주로 무슨 성씨로 구성되어 있습니까?',
#  '아아, 아까처럼 강씨 집, 홍씨 집, 처음에?',
#  '예.',
#  '그건 아는 사람이 없을 겁니다.',
#  '성씨가 제일 먼저?',
#  '예.',
#  '그거 아는 사람이 없을 겁니다.',
#  '신촌에는 성이 무신 성이 옛날에는 많았었습니까? 아까 강 씨 집, 홍씨 집.',
#  '아, 뭐 고씨도 많고, 김씨도 많고 거 그 성씨 야 상당히 많죠.',
#  '예.',
#  '주로 많이 있는 성 씨는 옛날부터 신촌하면 그런데 거기서 강 씨 집, 홍씨 집이 유명했었다는 거지요?',
#  '권세는 강씨 집, 홍씨 집 권세. 권세.',
#  '권세는요. 권세가 있다는 것은 부자였다는 것도 있고.',
#  '아, 아주.',
#  '학문을 했다는 것도 있고.',
#  '벼슬이요?',
#  '아아.',
#  '예.',
#  '물을 떠 다 드리니까 그 사 또가 손목을 잡았어.',
#  '어.',
#  '시집도 안 가고 허니까 열녀 비석이 있었어요.',
#  '예. 건 좀 너무 심하네요.',
#  '열녀문.',
#  '일생으로 봐서는 불쌍하지 않습니까?',
#  '그렇죠. 일생으로 봐서는 불쌍하죠.',
#  '이 마을 사람들은 주로 무슨 일들을 하며 살아가고 있습니까?',
#  '아아, 농토가.',
#  '농토가 좋아요.',
#  '무슨 농사를 지었는가요?',
#  '나? 아, 나는 뭐 한다는 거다 해봤어. 헤헤.',
#  '우리 어렸을 적에 보리를 많이 먹었어요. 보리밖에.',
#  '그렇죠. 많이 있었죠. 그렇죠.많이 있었죠.',
#  '거의 남자 분들은 어부라고?',
#  '해녀도 많이 있었죠.',
#  '오십 명 넘고?',
#  '어머니도 해녀였습니까?',
#  '아니요. 우리 집엔 해녀가 없었어요.',
#  '예, 예.',
#  '예.',
#  '북촌?',
#  '조천과 신촌 양 사이에 대섬이 있어.',
#  '아아, 그거는 신촌에 소속됐어?',
#  '조천 반, 신촌 반. 대섬.',
#  '조천 반.',
#  '반씩.',
#  '대섬 있군요.',
#  '예.',
#  '‘아다마’?',
#  '일본 말로.',
#  '‘아다마노 조뗑’?',
#  '‘아다마노’ 좋은?',
#  '‘조뗀’.',
#  '‘조뗑’ 뭐?',
#  '머리 좋은 조천.',
#  '좋다고, 좋다고?',
#  '‘조뗀’이요?',
#  '일본말로 ‘아다마노 조뗀!’',
#  '오름, 내, 천은 여기 없습니까?신촌에.',
#  '내는 없고 저 어디 ‘섯가름’.',
#  '예.',
#  '아아.',
#  '그렇군요? 뭐 굴이라든가 바다엔 없습니까? 굴?',
#  '바다에?',
#  '예.',
#  '바다에 굴?',
#  '굴, 동굴?',
#  '없어. ‘고깃집’이라고 한 데 있어.',
#  '신촌에?',
#  '동굴 닮은 거?',
#  '아아.',
#  '아아.',
#  '그렇게 해녀들이 힘들어.',
#  '물도 들었다 나왔다 하는 데로구나 거기가?',
#  '아아.',
#  '고기들만 놀아.',
#  '아아.',
#  '아아.',
#  '좁으니까. 거긴 고기들만 사는 데.',
#  '지금도 물 썰 때 이렇게 갈 수 있어요?',
#  '들면 막 깊어. 거기는.',
#  '깊어서 해녀들만 가는 데로구나?',
#  '그냥 사람들은 못 가.',
#  '거기 이름 ‘고깃집’이예요?',
#  '옛날은 옛날 할머니들, 해녀할머니들이 한청이라고 했어. ‘고기한청’이라고.',
#  '‘고기한청’? 야.',
#  '거기가 막 고기만 고기 떼로 사는데. ‘고깃집’, ‘고깃집’.',
#  '야, 바위 이런 큰 돌멩이 이런 것도 ‘고냉이 바위’ 여, 무슨 바위여.',
#  '그런 건 없고, 저 이여, 여 이름은 있어. 여 이름.',
#  '무슨 이름? ‘검은여’요?',
#  '아니, 아니. ‘안조각여’.',
#  '‘안조각여’.',
#  '응. ‘세조각여’.',
#  '해?',
#  '사이, 가운데.',
#  '‘새조각여’.',
#  '‘밧조각여’. 그 다음은 ‘안뿔여’.',
#  '‘안뿔여’?',
#  '응. 또 그 다음은 ‘밧뿔여’.',
#  '‘뿔여’가 뭡니까? ‘밧뿔여’?',
#  '그 이름이 그렇지.',
#  '아아, 안쪽에 붙여? 바깥쪽에?',
#  '‘안뿔여’, ‘밧뿔여’, ‘샛조각여’, ‘곤빌레’.',
#  '‘곤 빌레’, ‘곤 빌레’는 ‘빌레’라는 거 아니?',
#  '으응. 이 돌이 ‘빌레’라도 깨끗하니까 고운 ‘빌레’라고.',
#  '고운 ‘빌레’?',
#  '응. 여기서 말하면 예쁜 ‘빌레’라고 하는 거지. ‘곤빌레’, 옛날 할머니들.',
#  '바위 바위가?',
#  '여기는 바위가 없고.',
#  '예쁜 ‘빌레’, ‘곤빌레’?',
#  '아아.',
#  '나도 십이 미터 보통 들어갔었어. 전복만 떼.',
#  '아아.',
#  '전복밖에 안 떼. 소라도 안하고.',
#  '상군이었군요.',
#  '응. 막 바깥에, 여기 그 줄 있어. 나 했었던 줄, 가져오면 볼래?',
#  '아아, 나중에, 거 나중에 봐요.',
#  '막 깊은 열두 발, 십 이미터.',
#  '지금은 물질 안 합니까?',
#  '하이고, 걷지 못해서 못해.',
#  '그러니까 위험해.',
#  '이제도 바다에만 가면은 하는데, 걷지 못해. 넘어져서.',
#  '넘어져서요?',
#  '다리가 말 안 들어서, 그렇게만 안 하면 뭐 하지.',
#  '넘어져서.',
#  '넘어져서 안 돼.',
#  '큰일 나.',
#  '자빠져서. 그러니까 못 다녀. 넘어져서.',
#  '안 됩니다.',
#  '이 발이 말 안 들어.',
#  '예. 안 돼.',
#  '팔십 세까지요.',
#  '응.',
#  '신촌엔 오름이 없지요? 이 근방에.',
#  '원당봉 밖에 없죠.',
#  '오름 원당봉이요. 원당봉 반은 신촌 소속이고. 다음 내는?',
#  '아아.',
#  '‘웬당알’을.',
#  '그 ‘웬당알’ 신촌 구역입니까? 바다?',
#  '그렇죠.',
#  '삼양이 아니고?',
#  '예.',
#  '한전 이쪽은 신촌이죠.',
#  '아아, 고기가 많이 나고요?',
#  '예.',
#  '‘진드르’에 있는 ‘진드르’로 들어가는 데지요.',
#  '예. 그렇죠.',
#  '아니, 거긴.',
#  '닭 형치.',
#  '예.',
#  '이제 구경도 많이 오고 ‘웬당 알’가 이 저 어족이 풍부해 가지고.',
#  '어.',
#  '어족이 풍부해서.',
#  '어족이 풍부해서.',
#  '없는 고기가 없고 수심이 깊고 그러니까.',
#  '그렇구나. 굴도 없습니까? 굴?바다에 동굴?',
#  '그물이 굴속으로요?',
#  '그물이 그래서 그걸 겨우겨우 빼냈다는 말이 있는데.',
#  '그러니까 그게 고기굴이라고 합니까? ‘고기집’?',
#  '그렇죠. 고기가 그 굴속에 살죠.',
#  '사니까요.',
#  '자리도 살고.',
#  '거기가 저 ‘웬당알’에 있습니까? 것도?',
#  '예. 한전 옆에 있어요.',
#  '한전 옆에요. 삼춘 그 구멍에 들어가 봤습니까? 어릴 때?',
#  '아이고, 사람 못 들어가죠.',
#  '아아.',
#  '바다 속에.',
#  '해녀들은 들어갔다고 합디다. 이렇게 해서 아래로 이렇게 들어간?',
#  '그런 이야기가 있군요.',
#  '한전 옆에.',
#  '아니 바닷속이니까.',
#  '바닷속에 굴이 있다는 거지요.',
#  '그러니까 이 마을에 노인당은 세 개나 있다고 하던데요?',
#  '경로당 동부, 서부?',
#  '아아.',
#  '여기 동동, 중동.',
#  '동동이 큽니까?',
#  '아이구, 노인회장님도 잘도 똑똑하시던데요.',
#  '이 마을에는 무슨 기관이 있습니까? 기관이라고 하면.',
#  '노인당, 경로당.',
#  '예. 노인당은 각 동마다 다 있어요.',
#  '각 동마다 몇 개? ‘서카름’, ‘동카름’ 이렇게?',
#  '이제는 통합 헹 두 군데밖에 없다고 합디다.',
#  '신촌에?',
#  '예.',
#  '옛날엔?',
#  '아, 옛날엔 두 군데 각 동마다 다 지었어요.',
#  '대수동 있고 중동엔 없고 여기 중동엔 없고 상동에 있고.',
#  '아아, 그러면 총 네 개가 있다는 거네요?',
#  '옛날에는 여기예요 무슨 접이나 계, 어촌계.',
#  '응.',
#  '어촌계는 언제? 삼촌 어릴 때부터 있었습니까?',
#  '아아. 신촌에서?',
#  '무슨 접, 접이 여 계 여, 상여계여, 상여 접이여?',
#  '건 ‘섯가름’.',
#  '‘섯가름’ 있었습니까?',
#  '그릇제여 뭐?',
#  '그러니까.',
#  '왜 돈이 되니까?',
#  '십이 미터면 내 키보다 몇 배는?',
#  '이 발로 다가 ‘노손’ 발로 다가 열두발.',
#  '십이 발 들어간다는 거예요?',
#  '어, 저기 있어. 노손, 야, 어머어마한데 들어갔더라. 이젠 보니까.',
#  '아아, 바다에 들어가면 뭐가 제일 무서워요?',
#  '아, 정말이요?',
#  '응.',
#  '그렇게 착해요?',
#  '아이고야야아.',
#  '곰방메만큼 뛰라! 하면 팔짝팔짝 뛰고?',
#  '아하, 가까이서도 봤었습니까?',
#  '가까이서도 하고 또 먼데 가서도 보이고 그거 날 궂으려고 하면 잘 다녀.',
#  '아아.',
#  '떼로 다녔어요?',
#  '주둥이는 뾰족 하고서는 그냥 쉑쉑쉑쉑 하면서.',
#  '무섭지 않으면서 무서워합니다. 상어 때문에?',
#  '음.',
#  '피비린내 나가지고.',
#  '피비린내 나가지고.',
#  '그런데 이젠 그런 상어에 사람 죽었다고 말은 없어. 옛날은.',
#  '아이구, 상어 이런 거 끊어 먹어버려. ‘물착물착’.',
#  '거 어렸을 때 봐 본 적은 없지요? 신촌에서?',
#  '상어는 안 봐봤지. 그 곰세기 ‘삘룩삘룩’ 뛰는 거. 그런 거는 계속 보지.',
#  '그렇게 해가면 일단 불턱으로 돌아옵니까? 그런 거 보이면?',
#  '그게 왜냐하면 날 궂으려고 하면 그게 나서 다녀. 바람이나 나서 다녀.',
#  '날 궂으려고 하면요.',
#  '일기.',
#  '음. 신촌에는 듬북, 감태도 많이 나옵니까?',
#  '어, 그거 이젠 없어.',
#  '이젠 없어요?',
#  '오염이, 저 ‘웬당알’ 있잖아. 저 발전소.',
#  '발전소 쪽이 ‘웬당알’라고 합니까?',
#  '바다가 하얗게 돼버렸어요?',
#  '그렇지. 완전히 이 색깔이라고 하니까. 저 냉장고 색깔.',
#  '아이고.',
#  '그러니까.',
#  '발전손 언제 생겼습니까?',
#  '발전소가 뭘 하는 뎁니까?',
#  '저 전기 있잖아.이 전기가 거기서 물 돌아가면서 이 발전.',
#  '아, 세상에.',
#  '다 거기로 발전소, 이거 전기발전소.',
#  '전기발전소가 필요하긴 한 건데?',
#  '바다가 익어버렸어요?',
#  '여가 죽어?',
#  '듬북, 감태는 어떻게 채취했습니까?',
#  '어릴 때부터 그렇게?',
#  '예.',
#  '예.',
#  '아아.',
#  '할머니가 배워줬군요. 어머니가 가르쳐준 게 아니고 물질은?',
#  '할머님한테 배운 겁니까? 이 모님한테 배운 겁니까?',
#  '아, 이거는 누구한테 배우지 않아. 자기 스스로 하는 거지.',
#  '그래도 할머니가 막 해오라, 해오라. 허니까 해 온 거 아니?',
#  '듬북, 감태도 다 여기 많이 났었습니까?',
#  '옛날에는?',
#  '옛날에는 감태, 뭐 감태, ‘곡제기’, ‘실겡이’, 막 나와. ‘노랑쟁이’.',
#  '‘곡제기’는 뭡니까?',
#  '아아.',
#  '보리가 막 잘돼. 그 ‘곡제기’가.',
#  '아아.',
#  '다른 이 제 듬북은 별로 안 돼. 이 ‘곡제기’ 듬북이 걸어.',
#  '아아.',
#  '소 ‘늘추럭’이 뭡니까?',
#  '소가.',
#  '침.',
#  '침 질질 나잖아. 그런 걸 나와. 이 저 ‘곡제기’가.',
#  '썩어 가면.',
#  '아아.',
#  '아아.',
#  '아아, 태워서요?',
#  '그게.',
#  '불로 태워서?',
#  '폭탄. 감태로?',
#  '고사리공출.',
#  '참.',
#  '예. 그러면 어촌계도 있고, 어촌계는 막 옛날에 있었던 건 아니지요?',
#  '계가 성창이지. 상여계도 있고.',
#  '상여할 때 그 집 지어 가지고.',
#  '아아 그 계.',
#  '접 그런 거 만드는 동네서.',
#  '‘소방산’이라고.',
#  '‘소방산’?',
#  '무엇을 위해서 상여계가 만들어지는 겁니까?',
#  '사람 죽으면 그 저 곱게 저.',
#  '수의 옷 입히고. 꽃, 꽃상여?',
#  '이 소리를 삼촌은?',
#  '상당히 많았어요. 노래도 나도 소리 많이 했어요. 나, 노래 잘합니다.',
#  '불러도 나 다른 노래 부르죠. 옛날 노래 부르죠.',
#  '아아.',
#  '하는 계도 있고.',
#  '그렇게.',
#  '계주가 먹고 도망 가버리면 계 주가 먹고.',
#  '응.',
#  '그런 것도 아직도 있다고 합디다.',
#  '지금도 여기도 몇 군데 있었어요.',
#  '다 치워 버렸어요?',
#  '지금도 몇 군데 있어.',
#  '아아.지금도 상여 집은 있습니까? 개인 땅입니까? 오막살이 같은 초막.',
#  '그런데 바닷가에 개인 땅이 아니고 그저 나라의 땅이겠지 뭐.',
#  '예.',
#  '지금은 다 없어져 버렸지요.',
#  '다 없어졌죠.',
#  '그런 것들이 이제는 점점이요. 삼춘 역사네요.',
#  '참, 세상이 너무 바뀌었지요.',
#  '이 마을에는 어떤 풍습이 있습니까?',
#  '포제가 있구요. 해녀 굿이 언제 그만둔지 기억납니까?',
#  '아이구, 막 오래여서 그만 둔지.',
#  '오래여. 메인심방 누구였습니까?',
#  '죽어버렸네. 그 심방.',
#  '신촌에 살았었습니까? 그 심방.',
#  '시에 심방 왔었습니까?',
#  '누군지 기억납니까?',
#  '한일 하숙이라고 하는 할머니인데 죽어버렸어. 그런데 막 오래된.',
#  '함덕 할머니 빌어다가 했던데요?',
#  '여기는 시엣 할머니 왔었는데 죽어 버렸어. 그만둬 버렸어.',
#  '시의 할머니 누군지 기억납니까?',
#  '한일 하숙이지. 그 저 부두에 가면 한 일 하숙이라고 간판 써서. 거기 할머니.',
#  '부르는 이름은 없고?',
#  '할아버지도 무당?',
#  '아니, 아니. 할머니만.',
#  '할머니 성은 뭔지 모르고?',
#  '김가 김씨, 김씨 일 거라. 나 알기에는.',
#  '그 전에는?',
#  '해녀 죽으면‘물굿’이라고 해서 더 크게도 합디다만 조천리는.',
#  '옛날 할머니 어렸을 때 다시 안 해버렸어. 신촌에도 큰 무당.',
#  '무당 많지.',
#  '옛날엔?',
#  '응.',
#  '응, 정두삼도 있고. 그 심방 이름이 정두삼이.',
#  '정두삼이? 그 분이 신촌?',
#  '신촌, 본래 신촌 사람, 심방 많지. 정두삼이도 있고.',
#  '신촌 분, 거기도 영등굿 했었고?',
#  '무슨 만택인지 모르고요?',
#  '몰라. 성 모르겠네.',
#  '만택이가 하다가 또?',
#  '하다가 그만둬버렸네.',
#  '그만둬버리고 김씨 할머니가 하다가 그만둬버리고?',
#  '본향당은 어디 있습니까?',
#  '‘일뤠당’ 있는데 요기, 작은 데.',
#  '집도 있고요.',
#  '집 없어. 그냥 요만큼 한 세멘으로 담 쌓아서.',
#  '삼촌도 거기 갔었습니까?',
#  '다니다가 고해버렸지. 연령이 많아버리니까.',
#  '예.',
#  '지금도 다니는 사람 있는가요?',
#  '‘일뤠 할망당’이요? 무슨 날 간 거 기억 안 납니까?',
#  '정월 이레날 가진 않고?',
#  '아니, 아무 때라도.',
#  '아이들 잘되라고요?',
#  '으음.',
#  '거, ‘섯가름’.',
#  '‘섯가름’, 건 무슨 당?',
#  '크게 보이던데 요 ‘동카름’ 사람들은 ‘섯가름’ 안가?',
#  '거기도 메인 심방은 정두삼이나 만택 씨?',
#  '으음. 그러면 ‘섯가름’에 당은 메인 심방은 누구였습니까?',
#  '거기 무당은 난 몰라. ‘섯동네’ 라버리니까 몰라. 여기로 ‘섯동네’ 일은 모르지.',
#  '그러면 삼촌 네요기 당은 정두삼씨가 매인 무당이었습니까?',
#  '무당은 안 빌어? 본향당은 아니로구나, ‘일뤳당’?',
#  '종기 나면요.',
#  '종기 나면은 거기 가오고.',
#  '삼촌은 몇 살까지 거기 ‘일뤳당’에 갔다는 말이지요?',
#  '종기 나면은 거기 가오고.',
#  '육십 때면?',
#  '육십, 팔십, 구십, 육십 때도 아주 넘었네.',
#  '이십 팔년 전 천구백년도?',
#  '육십댄가? 육십대도 아주 넘었네.',
#  '천구백년도?',
#  '영등굿 기억납니까? 배방선도 하고.',
#  '거 기억나지.',
#  '해녀들이 몇 명 그때 있었는가요?',
#  '오십 명은 됐습니까?',
#  '옛날엔?',
#  '오십 명 정도 있었어?',
#  '신촌에요? ‘동카름’, ‘서카름’ 다 합쳐서?',
#  '아니, 아니. ‘동카름’만.',
#  '‘동카름’만.',
#  '바다에.',
#  '바다 밖에서 그냥 길 내서 거기서?',
#  '으음.',
#  '거, 개인 땅이라버리니까 그 집은 뜯어 버렸어. 뜯어 둬서 이젠.',
#  '아아.',
#  '해 신제요? 정월 해신제 원래는 그게 당굿으로.',
#  '어어.',
#  '옛날 할아버지들이.',
#  '포제 전에는 영등할머니한테.',
#  '아니, 포제 전에는 사람이 계속 죽었다고, 대풍에.',
#  '예.',
#  '해신제는 누구 무당도 안 오고 유교식으로?',
#  '생고기들 올리고?',
#  '음.',
#  '이제도 그렇게 해. 이제도 정월달은 이제도 그렇게 해.',
#  '영등굿 끝나면서 해신제로 더?',
#  '아니, 영등굿은 우리 해녀들 위해서 한 거고.',
#  '어부들이랑 해녀들이랑.',
#  '해신제로요?',
#  '옛날에 ‘영등굿’은 그 아까 포제집 있었던 데서 했다는 거지요?',
#  '응. 하다가 뜯어 버렸어.',
#  '거기에 그 바다에 ‘할망당’이 있지 않았을까?',
#  '없어.',
#  '바다에도 보면 영등하는 덴 다 당이 이십디다.',
#  '당이 여 기 거 들 먹이지. 여기 있어. 여기.',
#  '여기 건데 바다에 가서 하는구나.',
#  '아니, 거기 굿 하려고 하면 여기 굿합니다. 해서 밥 가져다가.',
#  '먼저.',
#  '‘손님질’ 하듯 그렇게만 해.',
#  '그렇게 해서 거기 가서 하는군요?',
#  '크게는 안해. 와서 거닐어 ‘섯가름’엔 막 크게 해. 당이라도.',
#  '음. ‘섯가름’에도 크게 하고요. 그 집 있는 데 거기서 합니까?',
#  '그 집이 안순옥이 살고 있을 거라.',
#  '바다도 아닌데 거기서 안 순옥이 가 누굽니까?',
#  '‘섯가름’ 사람이지.',
#  '왜 집이 없으니까 그 당 집을 빌어서 삽니까?',
#  '본래 자기네 집이었던 모양이었어.',
#  '무당은 아니고?',
#  '응.그 집 뒤에 그 할망당이 있어. 그 어른네 집 뒤에 당 있어.',
#  '개인이?',
#  '거기도 ‘할망당’이지요?',
#  '거기가 ‘본향당’ 같네요, 큰 당이네요?',
#  '신촌 김윤수 선생은 ‘칠머리 당굿’ 거기 가서?',
#  '아. 칠머리.',
#  '동네에서도 안 빌어. 외방은 가서 빌어 와도.',
#  '원래 신촌은 아닌가보다?',
#  '함덕 할머닌 빕니까? 있잖아요.',
#  '함덕, 그 저 인호 누인 잘 빌어다가 해.',
#  '예. 할머니요.',
#  '그 아들도 하고. 맞아. 인호누이, 요기 살고 있어. 그 저 오빠가.',
#  '아아 오빠가?',
#  '그러니까 아들도 물려.',
#  '그러니까요. 무당 팔자가요?',
#  '기구해요?',
#  '음. 이 마을에는 어떤 풍습이 있습니까? 소개할 만한 풍습 옛날에?',
#  '숲 나무라고 하면 원당봉입니까?',
#  '산에 가면 ‘바농벵듸’, ‘바농벵듸’ 더 가야죠.',
#  '‘바농벵듸’?',
#  '‘바농벵듸’ 넘어가야 그 숲속에 가야 좋은 나무 잘라다가 집도 짓고.',
#  '숲 속에 가서, 숲 속이라는 건 한라산을 말하는 거지요?',
#  '‘물터진골’?',
#  '‘물터진골’이라고 한 데가 그 저 ‘바농오름’ 제일 가까운 데 있는 데입니다.',
#  '‘물터진골’ 마을 이름이 뭐 선흘이라든가 이런.',
#  '선흘은 그 동쪽이고.',
#  '동쪽이고.',
#  '거기 가서 ‘새왓’도 하고요.',
#  '대흘 위에.',
#  '예?',
#  '대흘 위죠.',
#  '무슨 거?',
#  '풍습?',
#  '말은 못하고?',
#  '예.',
#  '지금도 하죠.',
#  '옛날에도 했습니까?',
#  '나가 ‘짐게제축’을 몇 해 했어.',
#  '삼촌 어릴 때 몇 살부터 이걸 봤습니까?',
#  '예.',
#  '음.',
#  '음.',
#  '봐야.',
#  '어어.',
#  '화북에 임이우.',
#  '비 우자.',
#  '아이고, 세상에.',
#  '그 선생이 제일 훌륭한 선생이었고.',
#  '그래서 그 분은 다 돌아가시고 화북에 살다가?',
#  '그러니까 죽었지.',
#  '예. 그렇군요.',
#  '하여튼 훌륭한 분이셨어.',
#  '삼촌 그때가 열 살 때요?',
#  '응.',
#  '참, 그때 거기 가보면 자식이 있습디까?',
#  '가보질 못했어요.',
#  '어디서 배웠습니까? 그러면 그 집에 가서 배운 게 아니고 화북?',
#  '여기 향사에서 와가지고.',
#  '아아.',
#  '선생님이 와서 배워 줬어요.',
#  '그분이 선생님으로 향사에 왔었군요.',
#  '예.',
#  '그렇죠.',
#  '조천만 그 학자들이 많다고 난 들었거든요?',
#  '이 저 거기가 이 저 동문 밖에선 제일 기와 집 지은 것이 저 신촌이에요.',
#  '아아.',
#  '지은 거?',
#  '그렇죠.',
#  '제단.',
#  '마을 제를 거기서 지 내고 있어요. 마을 젤.',
#  '난 사 삼 때에 그난 잘 모르겠어요. 난 떠나 버리니까.',
#  '아아, 그렇게 해서 삼촌 살았구나.',
#  '예.',
#  '이 마을의 특산물로는 어떤 것들이 있습니까?',
#  '특산물 별로 없을 거라.',
#  '이 마을의 특산물로는 어떤 것이 있습니까?',
#  '배추도 유명하지 않았습니까? 배추 수박?',
#  '아아, 땅이 좋으니까 이렇게 수박도 하고 무도 했군요?',
#  '수박도 해 보고 외도 놔보고 허허.',
#  '무가 제일 잘 됩디까? 삼촌은.',
#  '아이고 세상에.',
#  '더러 팔려버렸지만 열심히 했어.',
#  '그렇죠.',
#  '하는 사람이 드물어.',
#  '참외도 그렇고 무는 합니까? 아직까지. 귤로 많이 돌았는가?',
#  '귤로 많이 돌아버리니까 한데 무는 지금도 가는 사람들은 갈아.',
#  '지금도 갈고요. 귤로 저 유명해진 귤을 언제쯤부터 심었는가요?',
#  '아아.',
#  '이문행.',
#  '성은 이가고 이름은 문행.',
#  '이 문행씨가 처음 지었는데 그 분은 지금 돌아가 버리셨고.',
#  '동수동 강학수하고.',
#  '예? 강학수라는 분.',
#  '그렇지.',
#  '화북에.',
#  '문수창.',
#  '문수창이 보면서 이제 한 건데.잘되니까.',
#  '예.',
#  '또 다른 사람들이.',
#  '수확이 돈 많아 나니까.',
#  '응.',
#  '아아. 그러면 몇 평? 그땐 땅 없을 때잖아요.',
#  '예',
#  '무 갈아서 무말랭이 해서 벌고 그리저리 해서 버니까 막 샀어.',
#  '이 마을의 자랑거리는 무엇이 있습니까?',
#  '없어. 자랑거리가 무슨, 자랑거리 자랑할 일이 하나도 없어.',
#  '똑똑한 사람들 많이 나오지.',
#  '똑똑 이덕구 나왔다가 사 삼사건에 죽었지. 얽은 사람, 그 사람이.',
#  '여기가 고향?',
#  '고향이지. 여기서 큰 사람이지. 신촌 사람이라 그 사람.',
#  '그렇구나. 그 이외에 똑똑하고 유명한 사람은 나온 사람은 없습니까?',
#  '뭐 ‘대섬’이라든가 마을.',
#  '‘대섬’은 요기.',
#  '토지가 좋거나 뭐 경치 좋거나 뭐 이런 건 없습니까?',
#  '없어. ‘대섬’밖엔.',
#  '조천보다 신촌이 좋다하는 건 뭡니까?',
#  '신촌하고 조천하고 반반 ‘대섬’이.',
#  '음, 거기 ‘대섬’이 있으면 뭐가 좋습니까?',
#  '자랑거리에 들어가?',
#  '으응? 자랑거리? 그것이 발전될 건데 데모해버리니까.',
#  '아아.',
#  '거기 발전되면 발전소처럼 돼 버려.',
#  '발전 안 하는 게 더 좋은 거 아닌가?',
#  '이 마을에 자랑거리가 있으면 말씀해 주십시오.',
#  '신촌에 이 기빈이가 리 사무소 지어주었어.',
#  '사람 말고 또 자랑거리하면 뭐, 인심은 좋았습니까?',
#  '여자만 허는 목욕하는 물은?',
#  '왜 ‘가마물’인가요?',
#  '제일 물이 맛 좋은 덴 무슨 물이 없습니까?',
#  '가마 물은 물긷는 물하고 목욕하는 물이 따로 있었구나?',
#  '큰물에, ‘서카름’ 사람은 ‘큰물’에 여기로 가면.',
#  '어느 물이 좋다는 건 없어?',
#  '‘큰물’.',
#  '‘큰물’이 좋아.',
#  '살아오면서 신촌 마을이 뭐가 좋았습니까?',
#  '신촌에 물이 좋고.',
#  '무슨 물입니까? 여기는.',
#  '함덕이나 조천도 물이 있잖아요?',
#  '그래도 저 어릴 때 헤엄 치러 갈 수도 있지요? 그쪽에도.',
#  '아니, 여기 우리 바다가 있는데 왜 거기 가?',
#  '아아. 그래도.',
#  '‘큰물’이 좋아. 왜 가?',
#  '그래도 벗에게, 놂에.',
#  '그렇구나.',
#  '으응.',
#  '차가와.',
#  '이 ‘가마물’ 같지 않고 막 차가워.',
#  '자 이젠요. 삼촌이 낳고 자란 과정을 이야기해 주십시오.',
#  '천구백 몇 년생입니까?',
#  '내가 이십구년생.',
#  '천구백이 십 구 년생, 몇 번째 첫 번째 딸로 태어났다고 했잖아요?',
#  '어머니, 아버지 오랫동안 사셨습니까?',
#  '신촌에 살고?',
#  '외삼촌도 그럼 있었고?',
#  '외삼촌은 없고, 이모, 우리 어머니 아우, 동생.',
#  '이모도 시집가지 않았어?',
#  '‘히로시마’ 뭐 이런 데서.',
#  '어, ‘히로시마!’',
#  '원자폭탄.',
#  '아이고 직접 피해자로군요.',
#  '할머니가 막 속상했겠네요.',
#  '할아버진 없었고?',
#  '아들은 없었습니까?',
#  '그 이모가 더 의지됐구나. 어머니보다?',
#  '삼촌 몇 살에 어머니가 돌아가셨어요?',
#  '어머니가 한이 맺혔겠네요.',
#  '그런데 오래 살지 못했군요?',
#  '우리 어머니?',
#  '아들.',
#  '그래도 결혼해서 다 살긴 사니까.',
#  '결혼했는데 애기 없었어.',
#  '아이고.',
#  '몇 년 살아도 자식이 없었어.',
#  '아이고, 옛날에도 그렇게 했군요?',
#  '여자가 없는 애기.',
#  '그러면 아이고 결국은 씨가 없었구나.',
#  '쯧쯧. 몇 살 차이가 되는 겁니까?',
#  '우리 오빠가 쉰둘에 죽고.',
#  '우리 동생이 이제 여든 넷.',
#  '그렇게 공들여서 키웠나요?',
#  '은이 여 금이 여 했지. 그렇게 하 보니까 죽어버렸어.',
#  '그래도 의는 좋았습니까? 삼촌하고도 이 모하고도?',
#  '걔가 일본 살았지.',
#  '아이고.',
#  '죽으니까 여기 신장으로 왔어.',
#  '아이고!',
#  '보지도 못 했어.',
#  '태워서 옵니까? 태워서 시체를?',
#  '그렇게도 합니까?',
#  '응. 일본서 신장으로 왔더라고.',
#  '아이고야.',
#  '이제 죽은 지가 몇 십 년이라.',
#  '일본서 살다가.',
#  '응. 일본서 죽었어.',
#  '왜 일본까지 갔는가요?',
#  '돈벌레.',
#  '아, 신촌도 일본 많이 갔군요?',
#  '그 집은 누가?',
#  '양녀라고 합니까? 어디서 외로워서.',
#  '어린 때에 주워다가 키운 거',
#  '부모님은 어떤 일을 하셨습니까?',
#  '늘그막엔 농사지었지.',
#  '어머님의 고향은 어디십니까?',
#  '신촌, 강씨.',
#  '어릴 땐 어떤 놀이를 하며 자랐습니까?',
#  '일만 했습니까? 놀 때 숨바꼭질이다, 무신 줄넘기다?',
#  '아아, 건 어릴 때.',
#  '어떤 놀이?',
#  '어릴 땐 줄넘기하고.',
#  '줄넘기.',
#  '이렇게, 이렇게 해서 이렇게 둘이 쥐어서 그러면 이렇게, 이렇게 막 뛰지.',
#  '거 뭐?',
#  '이렇게 둘이 고무줄 있잖아.',
#  '아아, 고무줄놀이?',
#  '그러면 고무줄로 막.',
#  '아아. 고무줄놀이? 아아 노래라도 불렀습니까?',
#  '거 이, ‘이찌게츠람뽕 하루스시데!’ 하면서 일본 말로.',
#  '‘이찌게츠’.',
#  '공기놀이?',
#  '또 그 이렇게 띄우는 거 ‘오지다마’이라고 한 거.',
#  '‘오지다마’?',
#  '‘오지다마?’',
#  '뭐 바치고, 바치고 이런 거?',
#  '야, 학교 갈 때도?',
#  '고무신, 검은 겁니까? 흰 것입니까?',
#  '볼펜, 숯검정 볼펜?',
#  '드라마 이런 거에 나오는 거 보면요?',
#  '그래도 아버지도 생각은 하는군요?',
#  '아버지? 생각은 무슨 놈의 생각? 각시만 쳐 얻어서.',
#  '그래도 사삼 때 삼촌 그래도 그렇게 해서?',
#  '아버지가 있으니까 그래도.',
#  '살아놓고 뭘 해도.',
#  '삼촌 뭐 됐구나.',
#  '그러면 어떻게 하나? 이녁 어머니 내버려두고 이녁이 살려고 하니까.',
#  '그렇지. 살아놓고 뭘 해야지.',
#  '일제시대 때가 삼촌이 몇 살 될 철입니까? 천구백십구년이니까?',
#  '어디 갔는지 죽었는지 살았는지 소식이 없어. 그 사람.',
#  '보리, 조, 이런 거 다 공출?',
#  '일본 순사들 칼찬 것도 보고 말 타서 다니는 것도 봤습니까?',
#  '사십오 년도니까 몇 년에 태어났습니까?',
#  '대정 십삼 년에.',
#  '십삼 년이면 일제시대 네요? 한일합방이 천구 백십 년이니까.',
#  '그러면 일본말도 잘 알겠네요?',
#  '조금 알았지. 뭐.',
#  '사삼사건 때 소개 등 생활 전반과 겪었던 내용을 말씀해 주십시오.',
#  '그 동창들은 다 어디 갔습니까?',
#  '하나도 없어.이제. 다 죽언. 이제. 사삼사건에 다 죽어 버렸어.',
#  '사삼 때 세상에?',
#  '다 사삼 때?',
#  '한두 명 재수 좋게 산 사람도 있긴 있어요?',
#  '없어. 없어. 나밖에 없어.',
#  '사삼 때 산 사람도 있긴 있었지요?',
#  '사삼 때 남자 다 죽 여버렸어. 이 덕구 세계라 버리니까.',
#  '맞아.',
#  '여자들도 너무 고와도 안 되었겠습니다?',
#  '그러니까. 걸리면.',
#  '그 사람들은 빨갱이 아냐.',
#  '너무 고와도 또 순경이 그걸 뭐 해 가지고 점 찍어서 놔두면 또.',
#  '아아.',
#  '산엔 안 가봤습니까?',
#  '산엔 안 가 왔지. 산엔 폭도나 가지. 산에 안 가고 안에서만.',
#  '숨으러.',
#  '산엔 안 가오고, 여기야 이 안에서만.',
#  '조천에도.',
#  '조천엔 숨으러 안 다녀.이 덕구 세계니까 신촌이.',
#  '그러면 신촌에 사람들이 조천으로 많이 가기도 했겠네요?',
#  '아아, 그러니까.',
#  '난 아버지가 있으니까. 아버지가.',
#  '동생이랑 같이 갔습니까? 세 명이?',
#  '아니, 우리 아운 어릴 때니까.',
#  '음. 잠깐 쉬어요.',
#  '삼촌네가 무섭지. 여자들이.',
#  '아이구.',
#  '뛰는 걸 워낙 소문나게 뛰어버리니까.',
#  '하하하하하.',
#  '‘비 니쥬규’, 일본 말로, 제트기 비이십구.',
#  '운동신경이 발달해버리니까.',
#  '가운데.',
#  '큰아들이 지금 몇 살이에요?',
#  '세 살 차이.',
#  '예. 열일곱 살이구나?',
#  '‘빗게’.',
#  '군인이 주둔한 데가 어딘데 여기 신촌만 들어서 막 이덕구 때문에?',
#  '아아.',
#  '북촌은 전멸해서. 어이구.',
#  '그 난 북촌은 전멸했다고요. 남자들다?',
#  '빨갱이 북촌은 전멸시켜 버렸어.',
#  '왜 북촌은 그렇게 했는가요?',
#  '거기가 빨갱이가 많아버리니까.',
#  '똑똑한 사람이 꽤 있었나보네요.',
#  '쯧쯧쯧쯧. 삼춘은 그런 거 저런 거 다 봤겠네요? 불태우는 거랑.',
#  '삼촌도 해봤어요?',
#  '거 덮었지. 덮으라고 하면 안 덮어지나 거기.',
#  '누구 아는 사람도 없는 데도 간?',
#  '열일곱 살이면 끔찍했겠네요?',
#  '아이고.',
#  '재수 없이 걸리면?',
#  '삼촌네 친구들 똑똑한 아이들 있었습니까?',
#  '다 산에 올라갔습니까?',
#  '산에도 올라가고 잡아서도 다 죽여 버리고, 그러니까 없어. 없어.',
#  '삼촌 좋아했었던 남자아이는 있었습니까?',
#  '야이, 좋아했던 남자가 어디 있나? 정신 빠진 아이야 야야.',
#  '아니, 학교 다닐 때부터 그런 친구들?',
#  '아이고 무서웠네요? 동네 아이들 그래도 생각 날 때가 옛날 생각들?',
#  '여자들은?',
#  '여자들도 죽고, 남자들도 죽고.',
#  '여자들도 사삼 때 죽고?',
#  '삼촌은 안 올라갔네요?',
#  '몇 년간 살았습니까?',
#  '어?',
#  '조천에 간 몇 년? 일 년?',
#  '막 오래 살았어.',
#  '새어머니랑 같이 있었겠네?',
#  '큰어머니지.',
#  '큰어머니.',
#  '큰어머니 막 구박하고 그러진 않고?',
#  '거기 가서 일 했구나?',
#  '그때 아버지 처음 많이 봤구나.',
#  '응. 숨으러 간 살았지. 가기 싫어도 이덕구 세계였으니까.',
#  '그러니까.',
#  '잡으러 다녀가니까.',
#  '몇 년? 이, 삼년?',
#  '거기 어머니네가 육남매,우리 어머님은 삼남매.',
#  '겐 거기 육남매랑 같이 살면서?',
#  '흩어졌어요? 지금 그 공부하러 간 사람도 돌아가시고 다?',
#  '하.',
#  '쯧쯧쯧쯧 운명이요.',
#  '아이고.',
#  '사삼 지나고 나서?',
#  '그렇지. 그러니까 아버지는 남자니까 어머니는 충격 받아서 죽어버렸어.',
#  '아아.',
#  '오래 안 살았어.',
#  '오래 안 살았어.',
#  '화로.',
#  '화로.',
#  '사상이라 버리니까요?',
#  '그래. 몰아가 버리니까 와보지도 못하고 죽어버렸지.',
#  '참, 서로가들 왜 그렇게?',
#  '우리 사 삼사건 만난 에 이구, 얼마나 힘들었냐?',
#  '‘빗게’도 사보고 나중에 사삼 끝나서 이렇게 마을에 성도 쌓았었습니까?',
#  '허.',
#  '허, 젊은 아이들만 한 겁니까?',
#  '응. 우리 또래.',
#  '민보단이? 몇 살부터 그렇게 한 거라? 어른들은 안하고?',
#  '몇 명씩 보초 서?',
#  '만세동산에?',
#  '그러니까.',
#  '‘게이까이가이죠’.',
#  '‘구쇼’하면.',
#  '‘구쇼’.',
#  '아아, ‘가이죠’.',
#  '아아.',
#  '아, 그러니까 삼촌이 살았구나.',
#  '주정공장은 뭡니까?',
#  '저 그 옛날 그 동부 두 우에 주정공장이 있었죠. 동부두에.',
#  '예. 고구마, 고구마 찌꺼기로 주정공장 아?',
#  '인천, 아이고야?',
#  '아무도 아는 사람도 없는데 무조건 살려고?',
#  '죽었죠.',
#  '거기 못 갔으면 죽어.',
#  '다 돌아가셨더라고요.',
#  '세상에, 그래서 몇 년을 숨어서 살다가 왔습니까?',
#  '아, 인천에 가서 인천에 가가지고 오년 살았어요.',
#  '돌아와 보니까 뭐라고 하는 사람 없었습니까?',
#  '육이오 나니까 왔죠.',
#  '아이고, 세상에.',
#  '육이 오 때 그냥 또 죽을 뻔 했어요. 인천서. 음.',
#  '군인 갔다가?',
#  '허.',
#  '월미도? 세상에. 그 아이들은요?사촌.',
#  '왜요? 잘못한 것도 없는데?',
#  '제주도니까 빨갱이라고 해가지고.',
#  '아아 세상에, 아이고야.',
#  '동생이 형무소에 죽었단 말이야.',
#  '아아, 그렇게 하니까.',
#  '둘째 동생은 내가 데리고 가서 할 일 없으니까 군인 보내 버리니까.',
#  '살고.',
#  '군인 보냈지.',
#  '아이고 세상에.',
#  '그래도 어떻게 잘 나왔네요? 하늘에 뜻으로.',
#  '죄도 없었고.',
#  '결국은 사십삼일 갇혀서, 그 영창에 놓으니까.',
#  '야하!',
#  '나오니까 그냥 콕콕 박아져서 사람이.',
#  '먹지 못 했고.',
#  '사람이 아주 그냥 저 세 발자국을 놓지 못 해. 그냥 박아져서.',
#  '아이고 세상에.',
#  '굶고 먹을 거 안 주니까 굶고.',
#  '그때가 스물 몇 살 때네요. 젊은 나이에?',
#  '아이고, 세상에.',
#  '아.',
#  '인천에서?',
#  '군인들 와서 그냥 총 쏘고.',
#  '월미도?',
#  '예.',
#  '무서워서?',
#  '인천상륙작전. 예. 그래서 어디로? 제주도로 올 수 있었습니까?',
#  '아, 그러니까. 이젠.',
#  '군인 갔습니까?',
#  '음.',
#  '거기서 회복하고.',
#  '예.',
#  '군인은 안 갔습니까?',
#  '살려고 하니까.',
#  '아아, 안 갈 수가 없지요?',
#  '아이고.',
#  '쯧쯧쯧쯧. 결혼도 안하고? 와 보니까 어머니 아버지 살아 있었어요?',
#  '큰아들이고요.',
#  '어디 살고 있습니까? 아우는?',
#  '왜 그렇게 했을까요?',
#  '그게 나쁜 사람들이지.',
#  '아이고, 형인데. 형님이 있는데.',
#  '나가 형이라고 할 수도 없고 동생이라고 할 수도 없고.',
#  '아이고, 이런, 참 여동생은 연락하고요?',
#  '어디 삽니까?',
#  '저 어디? 신제주 그 저 노형.',
#  '아, 노형. 노형에 시집갔군요?',
#  '아니, 남군에 저 대포라고 한 데 시집은 갔는데',
#  '이○○이라고 했는데.',
#  '이○○?',
#  '어.',
#  '여든 일곱이요?',
#  '지금 오일장 바로 위쪽 될 거야.',
#  '그러면 월랑이네요.',
#  '삼촌은 아예 모르는구나. 어머니한테.',
#  '왜 삼촌은 안 잡혀갔는가요?백도 없는데.',
#  '아니, 그냥 봐져야 잡아가지 숨어버렸는데.',
#  '디 저 동굴이나 곶자왈 그런데 숨었습니까?',
#  '왜 그 옷을 입었어요? 밭 갈러 갈건데.',
#  '아니 폭도가.',
#  '폭도 아니라는 걸 증명하려고?',
#  '아이고 삼촌이 살려고 하니까 진짜, 옷이라도 증거가 있으니까 했구나.',
#  '군인 복 입어서?',
#  '대담하네요.',
#  '시로 강 또 인천에 갔습니까?',
#  '신촌이 무서워 보이니까 그때가 몇 년도입니까?',
#  '천구백사 십팔년 그러니까 삼촌이 아직 인천에 갔다가 외할머니 댁에 왔구나.',
#  '아이고, 것도 한 번 더 죽을 뻔했구나.',
#  '그 후 만나지 못했지요?',
#  '만나지 못했어.',
#  '야! 인연이란 게 신기하네요.',
#  '북초등학교요. 삼촌 어디 제주시 숨어 있었나요?',
#  '조천, 함덕보다 신촌이 피해가 많았다고요?',
#  '할머니 며칠 있었습니까?',
#  '중매 결혼을 하셨습니까? 연애 결혼을 하셨습니까?',
#  '그래서 어디서 결혼했습니까?',
#  '조천에서, 아버지.',
#  '아버지 집으로 갑니까?',
#  '마당에서 초례청?',
#  '말 타서 가마 타고 그런 게?',
#  ' 어머니가?',
#  '그렇지.',
#  '어머니가 뽑은 거?',
#  '어머니가 뽑은 거라. 이 제 있었으면 막 싸울 거 막 싸워.',
#  '것 때문에.',
#  '것 때문에 싸우지.',
#  '나중에 결혼해서?',
#  '그런 얘기 들으니까 또 어머니한테 뭐라고 했구나?',
#  '이 고생시키려고 없는 사람.',
#  '하하하하.',
#  '아아.',
#  '얼굴 잘 생겼어요?',
#  '원호 선생? 지레 조그만 해도 영리한 사람이더라고. 똑똑해.',
#  '운명이요?',
#  '한림 사람, 죽었을 거라.',
#  '하하하하.',
#  '농부?',
#  '농사꾼!',
#  '아이고 진짜 재미있네요.',
#  '학교 선생도 뭐 해도 좋은데.',
#  '하이고.',
#  '그래도 아버지가 그런 의 논을 잘 도 뭐 하네요?',
#  '그런데 다 일일이 보고 결정을 해야 되는데요.',
#  '그러니까 그 원호 선생이 한림 사람이라. 잘도 똑똑해. 원호 선생.',
#  '참 추적해보고 싶네요. 어떻게 살았는지?',
#  '결혼식 날 남편을 처음 본 거죠? 아저씨를 ?',
#  '응. 아니, 결혼한 날도 안 봤어.',
#  '이거 사진도 찍고?',
#  '응. 부끄러워서. 남자 보니까 부끄러워서, 도망가 버렸어.',
#  '세상에, 얼굴 보니까 마음에 안 들었습니까?',
#  '얼굴도 안 봐서 그냥 결혼해서, 며칠 있어가니까 이렇게 봤지.',
#  '잘 생겼어. 쟤네 아버지, 키도 크고, 군인 해병대로.',
#  '인물은 오케이네요?',
#  '몰라. 어머니가 인물을 봤을 수도 있겠다. 얼굴을?',
#  '인물이 좋았나 보다, 해녀 안 했을 건데.',
#  '거긴 시어머니나 이런 분 없었어요?',
#  '시아버지도 시어머니도 있고.',
#  '고생했겠네요? 큰아들?',
#  '아이고 고생했겠네? 시아버지, 시 어머니는 어떻게 괴롭히지 안 했어?',
#  '막 늙었더라. 육십이 넘으니까,막 늙어서.',
#  '밥해서 드리고 해야 되는 거?',
#  '할머니가? 물질하라고 막 욕한 할머니?',
#  '응. 그 할머니가 방법으로 먹으라고 한 거.',
#  '그렇게 열병 걸려서 다 돌아가셨어요?',
#  '아니, 다 살았어.',
#  '보리가 차가운 성분이지.',
#  '뭘 먹으니까 효과가 있습디까?',
#  '몇 년을 시 아버지, 시 어머니 모신 겁니까?',
#  '가며오며 별로 안 살았지.그저 갔다 왔다.',
#  '아, 조천에?',
#  '갔다 왔다 만 하면서 살지 않고, 쟤 네 아버지 군인 가버리고 해버리니까.',
#  '군인 가버리고 아저씨 이쪽으로 와버렸습니까?',
#  '아저씨도 나 신촌 사니까 이 리 와 버리고.',
#  '아, 어머니 아버지 내버려두고 이리로 와버렸어요? 가까우니까.',
#  '어머니, 아버지가 다 죽었네.',
#  '시어머님 시아버지가 다 죽어버렸어요?',
#  '능력 좋네요?',
#  '할아버지 능력도 좋아, 원.',
#  '각시 안 얻었으면 삼촌?',
#  '아이고야 고맙네.',
#  '결혼을 어떻게 된 겁니까? 중매입니까? 결혼을 어떻게?',
#  '어디 신촌에서요? 원래 신촌 여자?',
#  '그러면 군대 갔다 와서 아들 낳았군요?',
#  '결혼사진은 찍었습니까?',
#  '그때 사진이 어디 있니? 우리 사진 없어서.',
#  '가서 그냥 신촌리로 왔지.',
#  '거기서 며칠 살고?',
#  '그러면 바로 결혼하자마자 신촌에 와서 살았군요?',
#  '따로 집 빌었어. 남의 집 빌었어.',
#  '남의 집을 아예 하나 빌었어요?',
#  '아니, 작은 방.',
#  '작은 방 하나만?',
#  '주인은 혼자만 사는 사람?',
#  '아니, 둘이 사는 데 신랑은 군인 가버리니까.',
#  '음, 그렇게도 살았군요? ',
#  '응.',
#  '애기가 없이 있다가.',
#  '없이, 간 온 후에.',
#  '몇 년 살아서 왔습니까? 간 삼년 살아서 오니까?',
#  '삼년, 지원해서 해병대로 가왔잖아.',
#  '삼촌이 그때가 스무 살?',
#  '나가 스물여섯에 낳으니까.',
#  ...]
